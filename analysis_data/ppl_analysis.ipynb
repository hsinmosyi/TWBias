# %%
import re
import json
import numpy as np
import pandas as pd
import seaborn as sns

# %%
path = '/home/u3659277/master-thesis/TWBias/data/gender/result/Breeze-7B-Base-v0_1/Female/Breeze-7B-Base-v0_1_Female_category_None.csv'
df = pd.read_csv(path)
df
# Out:
#    Category  Type  t_statistic   p_value  statistically significant  count  \
# 0        其他    -1    -2.782385  0.006509                       True     96
# 1        其他     0          NaN       NaN                      False      1
# 2        其他     1    -1.829764  0.073020                      False     53
# 3        外貌     0    -1.413105  0.164505                      False     46
# 4        外貌     1    -0.961797  0.342232                      False     39
# 5        婚姻    -1    -1.343514  0.186678                      False     41
# 6      學術領域    -1    -1.494259  0.149314                      False     23
# 7        家庭    -1    -3.252612  0.004189                       True     20
# 8        年紀    -1     1.268528  0.208935                      False     69
# 9        性格     0    -0.042373  0.966333                      False     65
# 10       性格     1    -3.059538  0.002689                       True    132
# ...

# %%
title = path.split('/')[-1][:-4]
title = title.replace('_category_all_', "").replace('_category_', "")
# title = title.replace('_category_', "")
print(title)
# Out:
# Breeze-7B-Base-v0_1_FemaleNone

# %%
df = df.drop(1)
df
# Out:
#    Category  Type  t_statistic   p_value  statistically significant  count  \
# 0        其他    -1    -2.782385  0.006509                       True     96
# 2        其他     1    -1.829764  0.073020                      False     53
# 3        外貌     0    -1.413105  0.164505                      False     46
# 4        外貌     1    -0.961797  0.342232                      False     39
# 5        婚姻    -1    -1.343514  0.186678                      False     41
# 6      學術領域    -1    -1.494259  0.149314                      False     23
# 7        家庭    -1    -3.252612  0.004189                       True     20
# 8        年紀    -1     1.268528  0.208935                      False     69
# 9        性格     0    -0.042373  0.966333                      False     65
# 10       性格     1    -3.059538  0.002689                       True    132
# 11       職業    -1    -1.074575  0.288848                      False     42
# ...

# %%
# print(df['Category'].tolist())
# print(df['Type'].tolist())
# print(df['t_statistic'].tolist())

# %%
import plotly.express as px

# Ensure 'Type' is a category for proper legend representation in plotly
df['Type'] = df['Type'].astype(str)

# Define colors for each 'Type'
type_colors = {
    '-1': '#007acc',  # Dark Blue
    '1': '#47b5ff',   # Medium Blue
    '0': '#a3daff'    # Lighter Blue
}

orders = df['Category'].unique()

# Using plotly to create an interactive bar plot with custom colors
fig = px.bar(df, x='Category', y='t_statistic', color='Type', barmode='group',
             labels={'t_statistic': 't_statistic', 'Category': 'Category', 'Type': 'Type'},
             color_discrete_map=type_colors,  # Apply custom colors
             category_orders={'Category': orders}
             )

# Update layout for a clearer view
fig.update_layout(title=title,
                #   xaxis={'categoryorder': 'array'},
                  xaxis_title='Category',
                  yaxis_title='t_statistic',
                  legend_title='Type',
                  # yaxis_type="log",
                  )

fig.add_hline(y=0.05, line_dash="dash", line_color="#001f3f")

# Make the bars narrower
fig.update_traces(marker=dict(line=dict(width=2)))

# Update x-axis tick font size
fig.update_xaxes(tickfont=dict(size=18))
fig.update_yaxes(tickfont=dict(size=14))



# Show the figure
fig.show()
# Out:
# <div>                            <div id="ee51ab5a-c06e-43cf-b2e0-b8fa14e1982c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ee51ab5a-c06e-43cf-b2e0-b8fa14e1982c")) {                    Plotly.newPlot(                        "ee51ab5a-c06e-43cf-b2e0-b8fa14e1982c",                        [{"alignmentgroup":"True","hovertemplate":"Type=-1\u003cbr\u003eCategory=%{x}\u003cbr\u003et_statistic=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"-1","marker":{"color":"#007acc","pattern":{"shape":""},"line":{"width":2}},"name":"-1","offsetgroup":"-1","orientation":"v","showlegend":true,"textposition":"auto","x":["\u5176\u4ed6","\u5a5a\u59fb","\u5b78\u8853\u9818\u57df","\u5bb6\u5ead","\u5e74\u7d00","\u8077\u696d","\u8208\u8da3","\u8eab\u6750"],"x
# ...

# %%
import os
import plotly.express as px
import pandas as pd



def plot(file_path):
    df = pd.read_csv(file_path, dtype={'Type': str})
    # df = df.drop(1)

    # Define colors for each 'Type'
    type_colors = {
        '-1': '#007acc',  # Dark Blue
        '1': '#47b5ff',   # Medium Blue
        '0': '#a3daff'    # Lighter Blue
    }

    orders = df['Category'].unique()

    # Using plotly to create an interactive bar plot with custom colors
    fig = px.bar(df, x='Category', y='t_statistic', color='Type', barmode='group',
                labels={'t_statistic': 't_statistic', 'Category': 'Category', 'Type': 'Type'},
                color_discrete_map=type_colors,  # Apply custom colors
                category_orders={'Category': orders}
                )
    title = file_path.split('/')[-1][:-4]
    title = title.replace('_category_all', "").replace('_category', "")
    # Update layout for a clearer view
    fig.update_layout(title=title,
                    #   xaxis={'categoryorder': 'array'},
                    xaxis_title='Category',
                    yaxis_title='t_statistic',
                    legend_title='Type',
                    # yaxis_type="log",
                    width=800,  # Adjust width as needed
                    height=500  # Adjust height as needed
                    )

    fig.add_hline(y=0, line_dash="dash", line_color="#001f3f")

    # Make the bars narrower
    fig.update_traces(marker=dict(line=dict(width=0.5)))

    # Update x-axis tick font size
    fig.update_xaxes(tickfont=dict(size=18))
    fig.update_yaxes(tickfont=dict(size=14))

    file_name = file_path.split('/')[-1][:-4]    
    file_name = file_name.replace('_category_all', "").replace('_category', "") + '.png'

    print(file_name)
    # Show the figure
    fig.show()
    # fig.write_image("/home/u3659277/master-thesis/TWBias/data/gender/temp_all_plots/"+file_name)


# parent_dir = '/home/u3659277/master-thesis/TWBias/data/gender/result/'
# for d in os.listdir(parent_dir):
#     for file_path in os.listdir(parent_dir + d + '/Female'):
#         if 'category' in file_path and 'all' not in file_path:
#             plot(parent_dir + d + '/Female/' + file_path)

directory = "/home/u3659277/master-thesis/TWBias/data/gender/result/llama2-7b-ccw_cp-tw9_tv-0.5xwin-0.5tulu/Female" + "/"
for file_path in os.listdir(directory):
    if 'category' in file_path and 'all' not in file_path:
        plot(directory + file_path)
# Out:
# llama2-7b-ccw_cp-tw9_tv-0.5tulu2-0.5xwin_Female_sys.png
# ...

# %%
import os
import plotly.express as px
import pandas as pd

model_name_dict ={
    # 'Taiwan-LLM-7B-v2.1-chat':'Taiwan-LLM-7B-v2.1-chat',
    'Taiwan-LLM-7B-v2.0.1-chat':'Taiwan-LLM-7B',
    'Taiwan-LLM-13B-v2.0-chat':'Taiwan-LLM-13B',
    'Breeze-7B-Instruct-v0_1':'Breeze-7B',
    # 'llama2-7b-ccw_cp-tw9_tv-0.5tulu2-0.5xwin':'llama2-7B-tw9-TV',
    # 'llama2-13b-ccw_cp-tw9_tv-0.5tulu2-0.5xwin':'llama2-13B-tw9-TV',
    # 'llama2-7b-ccw_cp-n0_tv_0.5xwin-0.5tulu':'llama2-7B-n0-TV',
    # 'llama2-13b-ccw_cp-n0_tv_0.5xwin-0.5tulu':'llama2-13B-n0-TV',
    # 'llama2-7b-ccw_cp-n1_tv_0.5xwin-0.5tulu':'llama2-7B-n1-TV',
    # 'llama2-13b-ccw_cp-n1_tv_0.5xwin-0.5tulu':'llama2-13B-n1-TV'
    'llama2-7b-ccw_cp-p1_tv_ft-b8.3-capybara-mixed-e3_spin-1':'TAIDE 7B'
} 

# models = ['llama2-7b-ccw_cp-tw9_tv-0.5tulu2-0.5xwin',
#           'llama2-13b-ccw_cp-tw9_tv-0.5tulu2-0.5xwin',
#           'Taiwan-LLM-7B-v2.1-chat',
#           'Taiwan-LLM-13B-v2.0-chat',
#           'Breeze-7B-Instruct-v0_1'
#           'llama2-7b-ccw_cp-p1_tv_ft-b8.3-capybara-mixed-e3_spin-1'
#           ]
models = ['Taiwan-LLM-7B-v2.0.1-chat',
          'Taiwan-LLM-13B-v2.0-chat',
          'Breeze-7B-Instruct-v0_1',
          'llama2-7b-ccw_cp-p1_tv_ft-b8.3-capybara-mixed-e3_spin-1'
          ]

### Just modify here ###
origin = "Male" # Male / Female
replace = "T1" if origin == "Female" else "T2"
########################

def plot(model_paths):
    df_list = []
    # target = "Female" 
    parent_dir = "/home/u3659277/master-thesis/TWBias/data/gender/result" 
    model_names = [model_name_dict[model_path] for model_path in model_paths]

    for model_path in model_paths:
        model_name = model_name_dict[model_path]
        file_path = f"{parent_dir}/{model_path}/{origin}_{replace}/{model_path}_{origin}_{replace}_category_all_no_sys.csv"
        df = pd.read_csv(file_path)
        df['Model'] = model_name
        df_list.append(df)

    df = pd.concat(df_list, axis=0)

    # Define colors for each 'Type'
    colors = ['#007acc','#47b5ff','#FF9224','#01814A', '#007500' ]
    type_colors = dict(zip(model_names, colors))

    orders = df['Category'].unique()

    # Using plotly to create an interactive bar plot with custom colors
    fig = px.bar(df, x='Category', y='t_statistic', color='Model', barmode='group',
                labels={'t_statistic': 't_statistic', 'Category': 'Category', 'Type': 'Type'},
                color_discrete_map=type_colors,  # Apply custom colors
                category_orders={'Category': orders}
                )
    title = origin
    # title = title.replace('_category_all', "").replace('_category', "")
    # Update layout for a clearer view
    fig.update_layout(title={
                            'text': title,
                            'font': {'size': 25}  # 
                             },
                    #   xaxis={'categoryorder': 'array'},
                    xaxis_title='Category',
                    yaxis_title='t_statistic',
                    legend_title='Model',
                    # yaxis_type="log",
                    width=900,  # Adjust width as needed
                    height=500  # Adjust height as needed
                    )

    # fig.add_hline(y=0, line_dash="dash", line_color="#001f3f")

    # Make the bars narrower
    # fig.update_traces(marker=dict(line=dict(width=0.5)))

    # Update x-axis tick font size
    fig.update_xaxes(tickfont=dict(size=15))
    fig.update_yaxes(tickfont=dict(size=14))
    # fig.update_layout(legend=dict(title=dict(font=dict(size=20)))) 


    # file_name = file_path.split('/')[-1][:-4]    
    # file_name = file_name.replace('_category_all', "").replace('_category', "") + '.png'

    # print(file_name)
    # Show the figure
    fig.show()
    # fig.write_image("/home/u3659277/master-thesis/TWBias/data/gender/temp_all_plots/"+file_name)


# parent_dir = '/home/u3659277/master-thesis/TWBias/data/gender/result/'
# for d in os.listdir(parent_dir):
#     for file_path in os.listdir(parent_dir + d + '/Female'):
#         if 'category' in file_path and 'all' not in file_path:
#             plot(parent_dir + d + '/Female/' + file_path)

plot(models)
# Out:
# <div>                            <div id="e75dd51a-e9c1-4574-8f53-63330267cb9e" class="plotly-graph-div" style="height:500px; width:900px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e75dd51a-e9c1-4574-8f53-63330267cb9e")) {                    Plotly.newPlot(                        "e75dd51a-e9c1-4574-8f53-63330267cb9e",                        [{"alignmentgroup":"True","hovertemplate":"Model=Taiwan-LLM-7B\u003cbr\u003eCategory=%{x}\u003cbr\u003et_statistic=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Taiwan-LLM-7B","marker":{"color":"#007acc","pattern":{"shape":""}},"name":"Taiwan-LLM-7B","offsetgroup":"Taiwan-LLM-7B","orientation":"v","showlegend":true,"textposition":"auto","x":["Ability","Academic Field","Appearance\u002fImpression","Economics\u002fConsumption","Emotion\u002fAffection
# ...

# %%
import os
import plotly.express as px
import pandas as pd

model_name_dict ={
    # 'Taiwan-LLM-7B-v2.1-chat':'Taiwan-LLM-7B-v2.1-chat',
    'Taiwan-LLM-7B-v2.0.1-chat':'Taiwan-LLM-7B',
    'Taiwan-LLM-13B-v2.0-chat':'Taiwan-LLM-13B',
    'Breeze-7B-Instruct-v0_1':'Breeze-7B',
    # 'llama2-7b-ccw_cp-tw9_tv-0.5tulu2-0.5xwin':'llama2-7B-tw9-TV',
    # 'llama2-13b-ccw_cp-tw9_tv-0.5tulu2-0.5xwin':'llama2-13B-tw9-TV',
    # 'llama2-7b-ccw_cp-n0_tv_0.5xwin-0.5tulu':'llama2-7B-n0-TV',
    # 'llama2-13b-ccw_cp-n0_tv_0.5xwin-0.5tulu':'llama2-13B-n0-TV',
    # 'llama2-7b-ccw_cp-n1_tv_0.5xwin-0.5tulu':'llama2-7B-n1-TV',
    # 'llama2-13b-ccw_cp-n1_tv_0.5xwin-0.5tulu':'llama2-13B-n1-TV'
    'llama2-7b-ccw_cp-p1_tv_ft-b8.3-capybara-mixed-e3_spin-1':'TAIDE-7B'
} 

models = ['Taiwan-LLM-7B-v2.0.1-chat',
          'Taiwan-LLM-13B-v2.0-chat',
          'Breeze-7B-Instruct-v0_1',
          'llama2-7b-ccw_cp-p1_tv_ft-b8.3-capybara-mixed-e3_spin-1'
          ]

### Just modify here ###
origin = "Male" # Male / Female
replace = "T1" if origin == "Female" else "T2"
########################

def plot(model_paths):
    df_list = []
    # target = "Female" 
    parent_dir = "/home/u3659277/master-thesis/TWBias/data/gender/result" 
    model_names = [model_name_dict[model_path] for model_path in model_paths]

    for model_path in model_paths:
        model_name = model_name_dict[model_path]
        file_path = f"{parent_dir}/{model_path}/{origin}_{replace}/{model_path}_{origin}_{replace}_category_all_.csv"
        df = pd.read_csv(file_path)
        df['Model'] = model_name
        df_list.append(df)

    df = pd.concat(df_list, axis=0)

    # Define colors for each 'Type'
    colors = ['#007acc','#47b5ff','#FF9224','#01814A', '#007500' ]
    type_colors = dict(zip(model_names, colors))

    orders = df['Category'].unique()

    # Using plotly to create an interactive bar plot with custom colors
    fig = px.bar(df, x='Category', y='t_statistic', color='Model', barmode='group',
                labels={'t_statistic': 't_statistic', 'Category': 'Category', 'Type': 'Type'},
                color_discrete_map=type_colors,  # Apply custom colors
                category_orders={'Category': orders}
                )
    title = origin
    # title = title.replace('_category_all', "").replace('_category', "")
    # Update layout for a clearer view
    fig.update_layout(title=title,
                    #   xaxis={'categoryorder': 'array'},
                    xaxis_title='Category',
                    yaxis_title='t_statistic',
                    legend_title='Model',
                    # yaxis_type="log",
                    width=900,  # Adjust width as needed
                    height=500  # Adjust height as needed
                    )

    # fig.add_hline(y=0.05, line_dash="dash", line_color="#001f3f")

    # Make the bars narrower
    # fig.update_traces(marker=dict(line=dict(width=0.5)))

    # Update x-axis tick font size
    fig.update_xaxes(tickfont=dict(size=14))
    fig.update_yaxes(tickfont=dict(size=14))

    # file_name = file_path.split('/')[-1][:-4]    
    # file_name = file_name.replace('_category_all', "").replace('_category', "") + '.png'

    # print(file_name)
    # Show the figure
    fig.show()
    # fig.write_image("/home/u3659277/master-thesis/TWBias/data/gender/temp_all_plots/"+file_name)


# parent_dir = '/home/u3659277/master-thesis/TWBias/data/gender/result/'
# for d in os.listdir(parent_dir):
#     for file_path in os.listdir(parent_dir + d + '/Female'):
#         if 'category' in file_path and 'all' not in file_path:
#             plot(parent_dir + d + '/Female/' + file_path)

plot(models)
# Out:
# <div>                            <div id="97d9d920-c8af-4593-8f95-d16a4f025364" class="plotly-graph-div" style="height:500px; width:900px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("97d9d920-c8af-4593-8f95-d16a4f025364")) {                    Plotly.newPlot(                        "97d9d920-c8af-4593-8f95-d16a4f025364",                        [{"alignmentgroup":"True","hovertemplate":"Model=Taiwan-LLM-7B\u003cbr\u003eCategory=%{x}\u003cbr\u003et_statistic=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Taiwan-LLM-7B","marker":{"color":"#007acc","pattern":{"shape":""}},"name":"Taiwan-LLM-7B","offsetgroup":"Taiwan-LLM-7B","orientation":"v","showlegend":true,"textposition":"auto","x":["Ability","Academic Field","Appearance\u002fImpression","Economics\u002fConsumption","Emotion\u002fAffection
# ...

# %%
import os
parent_dir = '/home/u3659277/master-thesis/TWBias/data/gender/result/Taiwan-LLM-7B-v2.1-chat/Male'
for file in os.listdir(parent_dir):
    print(file)
    new_file = file.replace("_T2","")
    os.rename(f"{parent_dir}/{file}", f"{parent_dir}/{new_file}")
# Out:
# Taiwan-LLM-7B-v2.1-chat_Male_T2_category_.csv
# Taiwan-LLM-7B-v2.1-chat_Male_T2_output_no_sys_debias.csv
# Taiwan-LLM-7B-v2.1-chat_Male_T2_toxicity_no_sys.csv
# Taiwan-LLM-7B-v2.1-chat_Male_T2_category_no_sys.csv
# Taiwan-LLM-7B-v2.1-chat_Male_T2_toxicity_sys.csv
# Taiwan-LLM-7B-v2.1-chat_Male_T2_category_all_no_sys.csv
# Taiwan-LLM-7B-v2.1-chat_Male_T2_toxicity_.csv
# Taiwan-LLM-7B-v2.1-chat_Male_T2_category_sys.csv
# Taiwan-LLM-7B-v2.1-chat_Male_T2_category_all_sys.csv
# Taiwan-LLM-7B-v2.1-chat_Male_T2_output_.csv
# Taiwan-LLM-7B-v2.1-chat_Male_T2_category_no_sys_debias.csv
# Taiwan-LLM-7B-v2.1-chat_Male_T2_category_all_.csv
# Taiwan-LLM-7B-v2.1-chat_Male_T2_category_all_no_sys_debias.csv
# Taiwan-LLM-7B-v2.1-chat_Male_T2_toxicity_no_sys_debias.csv
# Taiwan-LLM-7B-v2.1-chat_Male_T2_output_no_sys.csv
# Taiwan-LLM-7B-v2.1-chat_Male_T2_output_sys.csv

# %%
import os
import plotly
import plotly.express as px
import pandas as pd

def plot(file_path):
    df = pd.read_csv(file_path, dtype={'Type': str})
    # df = df.drop(1)
    
    # Custom color scheme with shades of blue
    custom_blue_colors = ['#001f3f', '#003366', '#004080', '#00539b', '#007acc']

    # Using plotly to create an interactive bar plot
    fig = px.bar(df, x='Category', y='t_statistic',  
                labels={'Category': 'Category'},
                color_discrete_sequence=['#007acc']
                )

    # Update layout for a clearer view
    # Bar plot of p-value by Category
    
    title = file_path.split('/')[-1][:-4]
    title = title.replace('_category_all', "").replace('_category', "")

    fig.update_layout(font_family="Taipei Sans TC Beta",
                    title=title,
                    xaxis_title='Attribute Category',
                    yaxis_title='t_statistic',
                    # yaxis_type="log",
                    width=830,  # Adjust width as needed
                    height=500  # Adjust height as needed
                    ) 

    fig.add_hline(y=0, line_dash="dash", line_color="#001f3f")

    # Make the bars narrower
    fig.update_traces(marker=dict(line=dict(width=0.5)))  # Adjust the width value as needed
    

    # Update x-axis tick font size
    fig.update_xaxes(tickfont=dict(size=20))
    fig.update_yaxes(tickfont=dict(size=14))
    file_name = file_path.split('/')[-1][:-4]    
    file_name = file_name.replace('_category_all', "").replace('category_', "") + '.png'

    print(file_name)
    # Show the figure
    fig.show()
    
    # fig.write_image("/home/u3659277/master-thesis/TWBias/data/gender/temp_all_plots/"+file_name)

# parent_dir = '/home/u3659277/master-thesis/TWBias/data/gender/result/'
# for d in os.listdir(parent_dir):
#     for file_path in os.listdir(parent_dir + d + '/Female'):
#         if 'category_all' in file_path:
#             plot(parent_dir + d + '/Female/' + file_path)


directory = "/home/u3659277/master-thesis/TWBias/data/gender/result/llama2-7b-ccw_cp-tw9_tv-0.5xwin-0.5tulu/Female" + "/"
for file_path in os.listdir(directory):
    if 'category_all' in file_path:
        plot(directory + file_path)
# Out:
# llama2-7b-ccw_cp-tw9_tv-0.5tulu2-0.5xwin_Female_sys_debias.png
# ...

# %%
import plotly.express as px


# Custom color scheme with shades of blue
custom_blue_colors = ['#001f3f', '#003366', '#004080', '#00539b', '#007acc']

# Using plotly to create an interactive bar plot
fig = px.bar(df, x='Category', y='p_value',  
             labels={'Category': 'Category'},
             color_discrete_sequence=['#007acc']
             )

# Update layout for a clearer view
# Bar plot of p-value by Category

fig.update_layout(title=title,
                  xaxis_title='Attribute Category',
                  yaxis_title='p-value',
                  yaxis_type="log")

fig.add_hline(y=0.05, line_dash="dash", line_color="#001f3f")

# Make the bars narrower
fig.update_traces(marker=dict(line=dict(width=5)))  # Adjust the width value as needed

# Update x-axis tick font size
fig.update_xaxes(tickfont=dict(size=15))
fig.update_yaxes(tickfont=dict(size=14))


# Show the figure
fig.show()
# Out:
# <div>                            <div id="5f9ee3bd-d139-4027-8bda-16a099037dd2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5f9ee3bd-d139-4027-8bda-16a099037dd2")) {                    Plotly.newPlot(                        "5f9ee3bd-d139-4027-8bda-16a099037dd2",                        [{"alignmentgroup":"True","hovertemplate":"Category=%{x}\u003cbr\u003ep_value=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#007acc","pattern":{"shape":""},"line":{"width":5}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["\u5176\u4ed6","\u5916\u8c8c","\u5a5a\u59fb","\u5b78\u8853\u9818\u57df","\u5bb6\u5ead","\u5e74\u7d00","\u6027\u683c","\u8077\u696d","\u8208\u8da3","\u8eab\u6750"],"x
# ...

# %%
import plotly.express as px

# We'll use the same dataframe `df` as before

# Using plotly to create an interactive bar plot
fig = px.bar(df1, x='Category', y='t_statistic',  
             labels={'t_statistic': 't-statistic', 'Category': 'Category'},
             color_discrete_sequence=['#007acc']
             )

# Update layout for a clearer view

fig.update_layout(title='Bar plot of t-statistics by Category and Type',
                  xaxis_title='Category',
                  yaxis_title='t-statistic')

# Make the bars narrower
fig.update_traces(marker=dict(line=dict(width=20)))  # Adjust the width value as needed

# Update x-axis tick font size
fig.update_xaxes(tickfont=dict(size=15))
fig.update_yaxes(tickfont=dict(size=14))

# Show the figure
fig.show()
# Out:
# <div>                            <div id="4ab3b139-005e-40bc-8300-35049289866b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4ab3b139-005e-40bc-8300-35049289866b")) {                    Plotly.newPlot(                        "4ab3b139-005e-40bc-8300-35049289866b",                        [{"alignmentgroup":"True","hovertemplate":"Category=%{x}\u003cbr\u003et-statistic=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#007acc","pattern":{"shape":""},"line":{"width":20}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["\u5176\u4ed6","\u5916\u8c8c","\u5b78\u8853\u9818\u57df","\u5bb6\u5ead","\u6027\u683c","\u7d93\u6fdf\u80fd\u529b","\u8077\u696d","\u80fd\u529b","\u8208\u8da3","
# ...

# %%
import os
import math
import numpy as np
import pandas as pd
import plotly.graph_objects as go

model_name_dict ={
    'Taiwan-LLM-7B-v2.1-chat':'Taiwan-LLM-7B-v2.1-chat',
    'Taiwan-LLM-13B-v2.0-chat':'Taiwan-LLM-13B-v2.0-chat',
    'Breeze-7B-Instruct-v0_1':'Breeze-7B-Instruct-v0_1',
    'llama2-7b-ccw_cp-tw9_tv-0.5tulu2-0.5xwin':'llama2-7B-tw9-TV',
    'llama2-13b-ccw_cp-tw9_tv-0.5tulu2-0.5xwin':'lama2-13B-tw9-TV',
    'llama2-7b-ccw_cp-n0_tv_0.5xwin-0.5tulu':'llama2-7B-n0-TV',
    'llama2-13b-ccw_cp-n0_tv_0.5xwin-0.5tulu':'llama2-13B-n0-TV',
    'llama2-7b-ccw_cp-n1_tv_0.5xwin-0.5tulu':'lama2-7B-n1-TV',
    'llama2-13b-ccw_cp-n1_tv_0.5xwin-0.5tulu':'lama2-13B-n1-TV'
} 


## Draw heat map for ethical group
model_path = "/home/u3659277/master-thesis/TWBias/data/ethical_group/result/llama2-13b-ccw_cp-tw9_tv-0.5tulu2-0.5xwin"
model_name = model_path.split('/')[-1]
print(model_name)

fig_name = ''
for i in model_name_dict.keys():
    if i == model_name:
        fig_name = model_name_dict[i]
        print(fig_name) 


target_map = {
    'T5': 'Hakka',
    'T2': 'W',
    'T1': 'B',
    'T4': 'NT',
    'T3': 'H',
}

names = ['客家人', '外省人', '閩南人', '原住民', '漢人']

## Construct empty data
l = len(target_map)
data = np.full((l,l), np.nan)
t_data = np.full((l,l), np.nan)

for r, origin in enumerate(target_map.values()):
    for c, replace in enumerate(target_map.keys()):
        file_path = f"{model_path}/{origin}_{replace}/{model_name}_{origin}_{replace}_toxicity_.csv"
        if not os.path.exists(file_path): continue
        df = pd.read_csv(file_path)
        p_value = df.loc[2, 'p_value']
        t_value = df.loc[2, 't_statistic']
        data[r][c] = math.log(p_value, 10)
        t_data[r][c] = t_value

## flip data
data = data[::-1]
t_data = t_data[::-1]

## custom colorscale
max_v, min_v = np.nanmax(data), np.nanmin(data)
mid_v = math.log(0.05, 10)
mid_ratio = (mid_v - min_v) / (max_v - min_v)
print(min_v, max_v, mid_v, mid_ratio)

# Define custom color scale for different value segments
colorscale = [
    [0, '#cf3440'],  # Lower segment color scale 
    [mid_ratio, '#ffffff'],  # Middle segment color scale
    [1, '#4b8333']  # Upper segment color scale  #84917e
]
nan_color = "#a9a9a9"

fig = go.Figure(data=go.Heatmap(
    z=data, 
    x=names, 
    y=names[::-1], 
    colorscale=colorscale,
    colorbar=dict(title='log(p)')), 
    layout=go.Layout(
        plot_bgcolor=nan_color
    )
)

# Add symbols
for j in range(l):
    for k in range(l):
        t_value = t_data[j][k]
        # print(t_value)
        if np.isnan(t_value):
            continue
        elif t_value > 0:
            symbol = 'triangle-up'
            color = '#fadaba'
        else:
            symbol = 'triangle-down'
            color = '#20124d'
        fig.add_trace(go.Scatter(x=[names[k]], y=[names[-1-j]], mode='markers', marker=dict(symbol=symbol, size=20, color=color), showlegend=False))


fig.update_xaxes(showgrid=False)
fig.update_yaxes(showgrid=False)

fig.update_layout(
    title=fig_name,
    title_font=dict(size=22),
    yaxis_title='origin target',
    xaxis_title='replace target',
    xaxis=dict(tickfont=dict(size=17)),
    yaxis=dict(tickfont=dict(size=17)),
    width=600,
    height=600,
    title_x=0.5,
    xaxis_side='top',
    margin=dict(t=150),
    coloraxis_colorbar=dict(
        title='Color Scale',  # Colorbar title
        len=0.75,  # Length of the colorbar
        yanchor='bottom',  # Anchor point of the colorbar
        ticks='outside',  # Place ticks outside the colorbar
    ),
)

fig.show()
# Out:
# llama2-13b-ccw_cp-tw9_tv-0.5tulu2-0.5xwin
# lama2-13B-tw9-TV
# -19.32283874917474 -0.028391882606128772 -1.301029995663981 0.9340412232670455
# ...

# %%
import os
import math
import numpy as np
import pandas as pd
import plotly.graph_objects as go

model_name_dict ={
    'Taiwan-LLM-7B-v2.1-chat':'Taiwan-LLM-7B-v2.1-chat',
    'Taiwan-LLM-13B-v2.0-chat':'Taiwan-LLM-13B-v2.0-chat',
    'Breeze-7B-Instruct-v0_1':'Breeze-7B-Instruct-v0_1',
    'llama2-7b-ccw_cp-tw9_tv-0.5tulu2-0.5xwin':'llama2-7B-tw9-TV',
    'llama2-13b-ccw_cp-tw9_tv-0.5tulu2-0.5xwin':'llama2-13B-tw9-TV',
    'llama2-7b-ccw_cp-n0_tv_0.5xwin-0.5tulu':'llama2-7B-n0-TV',
    'llama2-13b-ccw_cp-n0_tv_0.5xwin-0.5tulu':'llama2-13B-n0-TV',
    'llama2-7b-ccw_cp-n1_tv_0.5xwin-0.5tulu':'llama2-7B-n1-TV',
    'llama2-13b-ccw_cp-n1_tv_0.5xwin-0.5tulu':'llama2-13B-n1-TV'
} 


## Draw heat map for ethical group
model_path = "/home/u3659277/master-thesis/TWBias/data/ethical_group/result_avg/Taiwan-LLM-7B-v2.1-chat"
model_name = model_path.split('/')[-1]
print(model_name)

fig_name = ''
for i in model_name_dict.keys():
    if i == model_name:
        fig_name = model_name_dict[i]
        print(fig_name) 


target_map = {
    'T5': 'Hakka',
    'T2': 'W',
    'T1': 'B',
    'T4': 'NT',
    'T3': 'H',
}

names = ['Hakka', 'W*', 'Hoklo', 'I*', 'Han']

## Construct empty data
l = len(target_map)
data = np.full((l,l), np.nan)
t_data = np.full((l,l), np.nan)

for r, origin in enumerate(target_map.values()):
    for c, replace in enumerate(target_map.keys()):
        file_path = f"{model_path}/{origin}_{replace}/{model_name}_{origin}_{replace}_toxicity_.csv"
        if not os.path.exists(file_path): continue
        df = pd.read_csv(file_path)
        p_value = df.loc[2, 'p_value']
        t_value = df.loc[2, 't_statistic']
        # data[r][c] = math.log(p_value, 10)
        data[r][c] = p_value
        t_data[r][c] = t_value

## flip data
data = data[::-1]
t_data = t_data[::-1]

## custom colorscale
max_v, min_v = np.nanmax(t_data), np.nanmin(t_data)
# mid_v = math.log(0.05, 10)
mid_v = 0
mid_ratio = (mid_v - min_v) / (max_v - min_v)
if mid_ratio < 0:
    mid_ratio = 0
elif mid_ratio > 1:
    mid_ratio = 1
print(min_v, max_v, mid_v, mid_ratio)

# Define custom color scale for different value segments
colorscale = [
    [0, '#cf3440'],  # Lower segment color scale 
    [mid_ratio, '#ffffff'],  # Middle segment color scale
    [1, '#4b8333']  # Upper segment color scale  #84917e
]
nan_color = "#a9a9a9"

fig = go.Figure(data=go.Heatmap(
    z=t_data, 
    x=names, 
    y=names[::-1], 
    colorscale=colorscale,
    colorbar=dict(title='t-statisti')), 
    layout=go.Layout(
        plot_bgcolor=nan_color
    )
)

# Add symbols
for j in range(l):
    for k in range(l):
        p_value = data[j][k]
        print(p_value)
        if np.isnan(p_value):
            continue
        if p_value < 0.05:
            symbol = 'star'
            color = '#20124d'
            fig.add_trace(go.Scatter(x=[names[k]], y=[names[-1-j]], mode='markers', marker=dict(symbol=symbol, size=20, color=color), showlegend=False))
            
        # t_value = t_data[j][k]
        # # print(t_value)
        # if np.isnan(t_value):
        #     continue
        # elif t_value > 0:
        #     symbol = 'triangle-up'
        #     color = '#fadaba'
        # else:
        #     symbol = 'triangle-down'
        #     color = '#20124d'


fig.update_xaxes(showgrid=False)
fig.update_yaxes(showgrid=False)

fig.update_layout(
    title={
        'text': fig_name,
        'font': {'size': 24},  # 设置标题字体大小为 24
        'x': 0.5,  # 将标题放置在图的中间位置
        'y': 0.05  # 将标题放置在图的底部
    },
    title_font=dict(size=22),
    yaxis_title='origin target',
    xaxis_title='replace target',
    xaxis=dict(tickfont=dict(size=17),titlefont=dict(size=20)),
    yaxis=dict(tickfont=dict(size=17)),
    width=600,
    height=600,
    title_x=0.5,
    xaxis_side='top',
    margin=dict(t=150),
    coloraxis_colorbar=dict(
        title='Color Scale',  # Colorbar title
        len=0.75,  # Length of the colorbar
        yanchor='bottom',  # Anchor point of the colorbar
        ticks='outside',  # Place ticks outside the colorbar
    ),
)

fig.show()
# Out:
# Taiwan-LLM-7B-v2.1-chat
# Taiwan-LLM-7B-v2.1-chat
# -5.962806464972766 -0.159255202987111 0 1
# nan
# nan
# nan
# nan
# nan
# 4.044876751756438e-07
# 7.425171249679411e-09
# 1.3049341832083844e-08
# nan
# 1.4456760053265686e-07
# 0.0002231752714565
# 1.3317828868722018e-06
# nan
# 0.0057447835531458
# 0.0007185367733379
# 0.8736166232423441
# nan
# 0.6154651041020246
# 1.2330162981574588e-07
# 2.0903966354663955e-06
# nan
# 0.012806235774387
# 3.4775035932347035e-05
# 0.0072638216827756
# 0.0182558498663959
# ...

# %%
import os
import math
import numpy as np
import pandas as pd
import plotly.graph_objects as go

model_name_dict ={
    # 'Taiwan-LLM-7B-v2.1-chat':'Taiwan-LLM-7B-v2.1-chat',
    'Taiwan-LLM-7B-v2.0.1-chat':'Taiwan-LLM-7B',
    'Taiwan-LLM-13B-v2.0-chat':'Taiwan-LLM-13B',
    'Breeze-7B-Instruct-v0_1':'Breeze-7B',
    # 'llama2-7b-ccw_cp-tw9_tv-0.5tulu2-0.5xwin':'llama2-7B-tw9-TV',
    # 'llama2-13b-ccw_cp-tw9_tv-0.5tulu2-0.5xwin':'llama2-13B-tw9-TV',
    # 'llama2-7b-ccw_cp-n0_tv_0.5xwin-0.5tulu':'llama2-7B-n0-TV',
    # 'llama2-13b-ccw_cp-n0_tv_0.5xwin-0.5tulu':'llama2-13B-n0-TV',
    # 'llama2-7b-ccw_cp-n1_tv_0.5xwin-0.5tulu':'llama2-7B-n1-TV',
    # 'llama2-13b-ccw_cp-n1_tv_0.5xwin-0.5tulu':'llama2-13B-n1-TV'
    'llama2-7b-ccw_cp-p1_tv_ft-b8.3-capybara-mixed-e3_spin-1':'TAIDE-7B'
} 


## Draw heat map for ethical group
model_path = "/home/u3659277/master-thesis/TWBias/data/ethical_group/result_avg/Taiwan-LLM-7B-v2.0.1-chat"
model_name = model_path.split('/')[-1]
print(model_name)

fig_name = ''
for i in model_name_dict.keys():
    if i == model_name:
        fig_name = model_name_dict[i]
        print(fig_name) 


target_map = {
    'T5': 'Hakka',
    'T2': 'W',
    'T1': 'B',
    'T4': 'NT',
    'T3': 'H',
}

names = ['Hakka', 'W*', 'Hoklo', 'I*', 'Han']

## Construct empty data
l = len(target_map)
data = np.full((l,l), np.nan)
t_data = np.full((l,l), np.nan)

for r, origin in enumerate(target_map.values()):
    for c, replace in enumerate(target_map.keys()):
        file_path = f"{model_path}/{origin}_{replace}/{model_name}_{origin}_{replace}_toxicity_no_sys.csv"
        if not os.path.exists(file_path): continue
        df = pd.read_csv(file_path)
        p_value = df.loc[2, 'p_value']
        t_value = df.loc[2, 't_statistic']
        # data[r][c] = math.log(p_value, 10)
        data[r][c] = p_value
        t_data[r][c] = t_value

## flip data
data = data[::-1]
t_data = t_data[::-1]

## custom colorscale
max_v, min_v = np.nanmax(t_data), np.nanmin(t_data)
# mid_v = math.log(0.05, 10)
mid_v = 0
mid_ratio = (mid_v - min_v) / (max_v - min_v)
if mid_ratio < 0:
    mid_ratio = 0
elif mid_ratio > 1:
    mid_ratio = 1
print(min_v, max_v, mid_v, mid_ratio)

# Define custom color scale for different value segments
colorscale = [
    [0, '#cf3440'],  # Lower segment color scale 
    [mid_ratio, '#ffffff'],  # Middle segment color scale
    [1, '#4b8333']  # Upper segment color scale  #84917e
]
nan_color = "#a9a9a9"

fig = go.Figure(data=go.Heatmap(
    z=t_data[1:], 
    x=names, 
    y=names[::-1][1:], 
    colorscale=colorscale,
    colorbar=dict(title='t-statistic',tickfont=dict(size=15))), 
    layout=go.Layout(
        plot_bgcolor=nan_color
    )
)

# Add symbols
for j in range(1,l):
    for k in range(l):
        p_value = data[j][k]
        print(p_value)
        if np.isnan(p_value):
            continue
        if p_value < 0.05:
            symbol = 'star'
            color = '#20124d'
            fig.add_trace(go.Scatter(x=[names[k]], y=[names[-1-j]], mode='markers', marker=dict(symbol=symbol, size=20, color=color), showlegend=False))

fig.update_xaxes(showgrid=False)
fig.update_yaxes(showgrid=False)

fig.update_layout(
    title={
        'text': fig_name,
        'font': {'size': 24},  # 设置标题字体大小为 24
        'x': 0.5,  # 将标题放置在图的中间位置
        'y': 0.05  # 将标题放置在图的底部
    },
    title_font=dict(size=22),
    yaxis_title='origin target',
    xaxis_title='replaced target',
    xaxis=dict(tickfont=dict(size=20),titlefont=dict(size=22)),
    yaxis=dict(tickfont=dict(size=20),titlefont=dict(size=22)),
    width=550,
    height=490,
    title_x=0.5,
    xaxis_side='top',
    margin=dict(t=150),
    # coloraxis_colorbar=dict(
    #     title='Color Scale',  # Colorbar title
    #     len=0.75,  # Length of the colorbar
    #     yanchor='bottom',  # Anchor point of the colorbar
    #     ticks='outside',# Place ticks outside the colorbar
    # ),
)

fig.show()
# Out:
# Taiwan-LLM-7B-v2.0.1-chat
# Taiwan-LLM-7B
# -8.30880862571546 -0.4866403461161604 0 1
# 9.121368629716989e-08
# 4.257427555345541e-15
# 1.7261649902807554e-11
# nan
# 7.53129867755414e-08
# 5.105790931346971e-09
# 1.6370249241366794e-09
# nan
# 2.4297231771019857e-08
# 4.875482613066765e-07
# 0.6270159386677814
# nan
# 0.6220936888408526
# 4.4852020221613327e-11
# 1.5984752872418212e-10
# nan
# 0.0029100474781381
# 4.445475498608387e-06
# 0.0042695924476957
# 0.0422551003192908
# ...

# %%
import os
import math
import numpy as np
import pandas as pd
import plotly.graph_objects as go

model_name_dict ={
    # 'Taiwan-LLM-7B-v2.1-chat':'Taiwan-LLM-7B-v2.1-chat',
    'Taiwan-LLM-7B-v2.0.1-chat':'Taiwan-LLM-7B',
    'Taiwan-LLM-13B-v2.0-chat':'Taiwan-LLM-13B',
    'Breeze-7B-Instruct-v0_1':'Breeze-7B',
    # 'llama2-7b-ccw_cp-tw9_tv-0.5tulu2-0.5xwin':'llama2-7B-tw9-TV',
    # 'llama2-13b-ccw_cp-tw9_tv-0.5tulu2-0.5xwin':'llama2-13B-tw9-TV',
    # 'llama2-7b-ccw_cp-n0_tv_0.5xwin-0.5tulu':'llama2-7B-n0-TV',
    # 'llama2-13b-ccw_cp-n0_tv_0.5xwin-0.5tulu':'llama2-13B-n0-TV',
    # 'llama2-7b-ccw_cp-n1_tv_0.5xwin-0.5tulu':'llama2-7B-n1-TV',
    # 'llama2-13b-ccw_cp-n1_tv_0.5xwin-0.5tulu':'llama2-13B-n1-TV'
    'llama2-7b-ccw_cp-p1_tv_ft-b8.3-capybara-mixed-e3_spin-1':'TAIDE-7B'
} 


## Draw heat map for ethical group
model_path = "/home/u3659277/master-thesis/TWBias/data/ethical_group/result_avg/llama2-7b-ccw_cp-p1_tv_ft-b8.3-capybara-mixed-e3_spin-1"
model_name = model_path.split('/')[-1]
print(model_name)

fig_name = ''
for i in model_name_dict.keys():
    if i == model_name:
        fig_name = model_name_dict[i]
        print(fig_name) 

target_list = [
    ('Hakka', 'T5', 'Hakka'),
    ('W', 'T2', 'W*'),
    ('B', 'T1', 'Hoklo'),
    ('NT', 'T4', 'I*'),
    ('H', 'T3', 'Han'),
]

## Construct empty data
l = len(target_list)
data_list = [] # shape = 4 x (4, # of Category)
category_list = [] # shape = 4 x (# of Category)
t_list = [] # shape = 4 x (4, # of Category)

for r in range(l):
    count = 0
    for c in range(l):
        origin = target_list[r][0]
        replace = target_list[c][1]
        file_path = f"{model_path}/{origin}_{replace}/{model_name}_{origin}_{replace}_category_all_.csv"
        if not os.path.exists(file_path):
            print(file_path, ": file not found!!")
            continue
        df = pd.read_csv(file_path)
        # Add new data & categories
        if count == 0:
            category_list.append(df['Category'])
            data_list.append(np.zeros((l - 1, len(df['Category']))))
            t_list.append(np.zeros((l - 1, len(df['Category']))))
            
        data_list[r][count] = np.log(df['p_value'])
        t_list[r][count] = df['t_statistic']
        count += 1

## flip data
for i in range(l-1):
    data_list[i] = data_list[i][::-1]
    t_list[i] = t_list[i][::-1]

## custom colorscale
mid_ratio_list = []
for i in range(l-1):
    max_v, min_v = np.nanmax(data_list[i]), np.nanmin(data_list[i])
    mid_v = math.log(0.05, 10)
    mid_ratio = (mid_v - min_v) / (max_v - min_v)
    mid_ratio_list.append(mid_ratio)
    
# ## custom colorscale
# max_v, min_v = np.nanmax(t_data), np.nanmin(t_data)
# # mid_v = math.log(0.05, 10)
# mid_v = 0
# mid_ratio = (mid_v - min_v) / (max_v - min_v)
# if mid_ratio < 0:
#     mid_ratio = 0
# elif mid_ratio > 1:
#     mid_ratio = 1
# print(min_v, max_v, mid_v, mid_ratio)

# Define custom color scale for different value segments
colorscale = [
    [0, '#cf3440'],  # Lower segment color scale 
    [mid_ratio, '#ffffff'],  # Middle segment color scale
    [1, '#4b8333']  # Upper segment color scale  #84917e
]
nan_color = "#a9a9a9"

## plot figures
for i in range(l-1):
    if i == l-2:
        print(category_list[i])
        print(data_list[i].shape)
        
    # y_labels
    y = [f"{target_list[i][2]}→{target_list[j][2]}" for j in range(l) if j != i]
    
    fig = go.Figure(data=go.Heatmap(
        z=data_list[i], 
        x=category_list[i], 
        y=y[::-1], # flip data 
        colorscale=colorscale,
        colorbar=dict(title='log(p)')), 
        layout=go.Layout(
            plot_bgcolor=nan_color
        )
    )
    
    # Add symbols
    for j in range(len(t_list[i])):
        for k in range(len(t_list[i][j])):
            t_value = t_list[i][j][k]
            # print(t_value)
            if t_value > 0:
                symbol = 'triangle-up'
                color = '#fadaba'
            else:
                symbol = 'triangle-down'
                color = '#20124d'
            fig.add_trace(go.Scatter(x=[category_list[i][k]], y=[y[-1-j]], mode='markers', marker=dict(symbol=symbol, size=15, color=color), showlegend=False))

    fig.update_xaxes(showgrid=False)
    fig.update_yaxes(showgrid=False)

    fig.update_layout(
        title=fig_name,
        title_font=dict(size=22),
        yaxis_title='origin target',
        xaxis_title='replace target',
        xaxis=dict(tickfont=dict(size=17)),
        yaxis=dict(tickfont=dict(size=13)),
        # width=120*len(category_list[i]),
        width = 1000,
        height=500,
        title_x=0.5,
        xaxis_side='top',
        margin=dict(t=150),
        coloraxis_colorbar=dict(
            title='Color Scale',  # Colorbar title
            len=0.75,  # Length of the colorbar
            yanchor='bottom',  # Anchor point of the colorbar
            ticks='outside',  # Place ticks outside the colorbar
        ),
    )

    fig.show()
# Out:
# llama2-7b-ccw_cp-p1_tv_ft-b8.3-capybara-mixed-e3_spin-1
# TAIDE-7B
# /home/u3659277/master-thesis/TWBias/data/ethical_group/result_avg/llama2-7b-ccw_cp-p1_tv_ft-b8.3-capybara-mixed-e3_spin-1/Hakka_T5/llama2-7b-ccw_cp-p1_tv_ft-b8.3-capybara-mixed-e3_spin-1_Hakka_T5_category_all_.csv : file not found!!
# /home/u3659277/master-thesis/TWBias/data/ethical_group/result_avg/llama2-7b-ccw_cp-p1_tv_ft-b8.3-capybara-mixed-e3_spin-1/W_T2/llama2-7b-ccw_cp-p1_tv_ft-b8.3-capybara-mixed-e3_spin-1_W_T2_category_all_.csv : file not found!!
# /home/u3659277/master-thesis/TWBias/data/ethical_group/result_avg/llama2-7b-ccw_cp-p1_tv_ft-b8.3-capybara-mixed-e3_spin-1/B_T1/llama2-7b-ccw_cp-p1_tv_ft-b8.3-capybara-mixed-e3_spin-1_B_T1_category_all_.csv : file not found!!
# /home/u3659277/master-thesis/TWBias/data/ethical_group/result_avg/llama2-7b-ccw_cp-p1_tv_ft-b8.3-capybara-mixed-e3_spin-1/NT_T4/llama2-7b-ccw_cp-p1_tv_ft-b8.3-capybara-mixed-e3_spin-1_NT_T4_category_all_.csv : file not found!!
# ...

# %%
import os
import plotly.express as px
import pandas as pd

model_name_dict ={
    # 'Taiwan-LLM-7B-v2.1-chat':'Taiwan-LLM-7B-v2.1-chat',
    'Taiwan-LLM-7B-v2.0.1-chat':'Taiwan-LLM-7B',
    'Taiwan-LLM-13B-v2.0-chat':'Taiwan-LLM-13B',
    'Breeze-7B-Instruct-v0_1':'Breeze-7B',
    # 'llama2-7b-ccw_cp-tw9_tv-0.5tulu2-0.5xwin':'llama2-7B-tw9-TV',
    # 'llama2-13b-ccw_cp-tw9_tv-0.5tulu2-0.5xwin':'llama2-13B-tw9-TV',
    # 'llama2-7b-ccw_cp-n0_tv_0.5xwin-0.5tulu':'llama2-7B-n0-TV',
    # 'llama2-13b-ccw_cp-n0_tv_0.5xwin-0.5tulu':'llama2-13B-n0-TV',
    # 'llama2-7b-ccw_cp-n1_tv_0.5xwin-0.5tulu':'llama2-7B-n1-TV',
    # 'llama2-13b-ccw_cp-n1_tv_0.5xwin-0.5tulu':'llama2-13B-n1-TV'
    'llama2-7b-ccw_cp-p1_tv_ft-b8.3-capybara-mixed-e3_spin-1':'TAIDE-7B'
} 
fig_name = ''
for i in model_name_dict.keys():
    if i == model_name:
        fig_name = model_name_dict[i]
        print(fig_name) 

parent_dir = "/home/u3659277/master-thesis/TWBias/data/ethical_group/result_avg"

### Just modify here ###
origin = "NT"
replace_target = "T1"
base_model_name = None
########################

origin_name = [t[2] for t in target_list if t[0] == origin][0]

target_list = [
    ('Hakka', 'T5', '客家人'),
    ('W', 'T2', '外省人'),
    ('B', 'T1', '閩南人'),
    ('NT', 'T4', '原住民'),
    ('H', 'T3', '漢人'),
]

replace_target_list = [t[1] for t in target_list if t[0] != origin]

prompt_list = ["", "no_sys", "no_sys_debias", "sys", "sys_debias"]

df_result = pd.DataFrame(columns=["model_name", "prompt_template", "replace_target", "p_value"])

for model_name in model_name_dict.keys():
    for prompt in prompt_list:
        for replace in replace_target_list:
            result_path = f"{parent_dir}/{model_name}/{origin}_{replace}/{model_name}_{origin}_{replace}_toxicity_{prompt}.csv"
            df = pd.read_csv(result_path)
            p_value = df.loc[2, 'p_value']
            replace_name = [t[2] for t in target_list if t[1] == replace][0]
            df_result = pd.concat([df_result, pd.DataFrame({"model_name": [model_name_dict[model_name]], 
                                                            "prompt_template": [prompt or "None"], 
                                                            "replace_target": [f"{origin_name}→{replace_name}"], 
                                                            "p_value": [p_value]})])


def plot(model_name = None, replace = None):
    # Define colors for each 'Type'
    type_colors = {
        'None': '#5B5B5B',  # Dark Blue
        'no_sys': '#668957',   # Medium Blue
        'no_sys_debias': '#93c47d',    # Lighter Blue
        'sys': '#f1c232',
        'sys_debias': '#f6da84',
    }

    x_column = 'replace_target' if model_name else 'model_name'
    
    orders = df_result[x_column].unique()
        
    # Using plotly to create an interactive bar plot with custom colors
    fig = px.bar(df_result, x=x_column, y='p_value', color='prompt_template', barmode='group',
                labels={'p_value': 'p_value', x_column: x_column, 'propmt_template': 'prompt_template'},
                color_discrete_map=type_colors,  # Apply custom colors
                category_orders={x_column: orders}
                )
    
    if x_column == "replace_target":
        title = model_name
        xaxis_title = "original target → replaced target"
    else:
        replace_name = [t[2] for t in target_list if t[1] == replace_target][0]
        title = f"{origin_name}→{replace_name}"
        xaxis_title = "model name"
        
    # Update layout for a clearer view
    fig.update_layout(title=fig_name,
                    #   xaxis={'categoryorder': 'array'},
                    xaxis_title=xaxis_title,
                    yaxis_title='p-value',
                    legend_title='prompt template',
                    yaxis_type="log",
                    width=800,  # Adjust width as needed
                    height=500  # Adjust height as needed
                    )

    fig.add_hline(y=0.05, line_dash="dash", line_color="#001f3f")

    # Make the bars narrower
    fig.update_traces(marker=dict(line=dict(width=0)))

    # Update x-axis tick font size
    fig.update_xaxes(tickfont=dict(size=18))
    fig.update_yaxes(tickfont=dict(size=14))

    # Show the figure
    fig.show()

plot(replace=replace_target, model_name=base_model_name)
# Out:
# TAIDE-7B
# ...

# %%
import os
import plotly.express as px
import pandas as pd

model_name_dict ={
    # 'Taiwan-LLM-7B-v2.1-chat':'Taiwan-LLM-7B-v2.1-chat',
    'Taiwan-LLM-7B-v2.0.1-chat':'Taiwan-LLM-7B',
    'Taiwan-LLM-13B-v2.0-chat':'Taiwan-LLM-13B',
    'Breeze-7B-Instruct-v0_1':'Breeze-7B',
    # 'llama2-7b-ccw_cp-tw9_tv-0.5tulu2-0.5xwin':'llama2-7B-tw9-TV',
    # 'llama2-13b-ccw_cp-tw9_tv-0.5tulu2-0.5xwin':'llama2-13B-tw9-TV',
    # 'llama2-7b-ccw_cp-n0_tv_0.5xwin-0.5tulu':'llama2-7B-n0-TV',
    # 'llama2-13b-ccw_cp-n0_tv_0.5xwin-0.5tulu':'llama2-13B-n0-TV',
    # 'llama2-7b-ccw_cp-n1_tv_0.5xwin-0.5tulu':'llama2-7B-n1-TV',
    # 'llama2-13b-ccw_cp-n1_tv_0.5xwin-0.5tulu':'llama2-13B-n1-TV'
    'llama2-7b-ccw_cp-p1_tv_ft-b8.3-capybara-mixed-e3_spin-1':'TAIDE-7B'
} 

# fig_name = ''
# for i in model_name_dict.keys():
#     if i == model_name:
#         fig_name = model_name_dict[i]
#         print(fig_name) 

parent_dir = "/home/u3659277/master-thesis/TWBias/data/gender/result_master"

### Just modify here ###
origin = "Male" # Male / Female
replace = "T1" if origin == "Female" else "T2"
########################

prompt_list = ["", "no_sys", "no_sys_debias", "sys", "sys_debias"]

df_result = pd.DataFrame(columns=["model_name", "prompt_template", "p_value", "t_value"])

for model_name in model_name_dict.keys():
    for prompt in prompt_list:
        # result_path = f"{parent_dir}/{model_name}/{origin}/{model_name}_{origin}_toxicity_{prompt}.csv"
        result_path = f"{parent_dir}/{model_name}/{origin}_{replace}/{model_name}_{origin}_{replace}_toxicity_{prompt}.csv"
        df = pd.read_csv(result_path)
        p_value = df.loc[2, 'p_value']
        df_result = pd.concat([df_result, pd.DataFrame({"model_name": [model_name_dict[model_name]], 
                                                            "prompt_template": [prompt or "None"], 
                                                            "p_value": [p_value]})])


def plot(origin):
    # Define colors for each 'Type'
    type_colors = {
        'None': '#5B5B5B',  # Dark Blue
        'no_sys': '#668957',   # Medium Blue
        'no_sys_debias': '#93c47d',    # Lighter Blue
        'sys': '#f1c232',
        'sys_debias': '#f6da84',
    }

    x_column = 'model_name'
    
    orders = df_result[x_column].unique()
        
    # Using plotly to create an interactive bar plot with custom colors
    fig = px.bar(df_result, x=x_column, y='p_value', color='prompt_template', barmode='group',
                labels={'p_value': 'p_value', x_column: x_column, 'propmt_template': 'prompt_template'},
                color_discrete_map=type_colors,  # Apply custom colors
                category_orders={x_column: orders}
                )
    
    
    xaxis_title = "model name"
        
    # Update layout for a clearer view
    fig.update_layout(title={'text': origin,'font_size': 25},
                    #   xaxis={'categoryorder': 'array'},
                    xaxis_title=xaxis_title,
                    yaxis_title='p-value',
                    legend_title='prompt template',
                    yaxis_type="log",
                    width=800,  # Adjust width as needed
                    height=500,  # Adjust height as needed
                    legend_title_font_size=18,  # Adjust legend title font size
                    legend_font_size=16,  # Adjust legend items font size
                    xaxis_title_font={"size": 20},  # Adjust x-axis title font size
                    yaxis_title_font={"size": 20}
                    )

    fig.add_hline(y=0.05, line_dash="dash", line_color="#001f3f")

    # Make the bars narrower
    fig.update_traces(marker=dict(line=dict(width=0)))

    # Update x-axis tick font size
    fig.update_xaxes(tickfont=dict(size=18))
    fig.update_yaxes(tickfont=dict(size=14))

    # Show the figure
    fig.show()

plot(origin)
# Out:
# <div>                            <div id="c4ca0130-859a-4e96-be4f-e2fd1c7b8982" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c4ca0130-859a-4e96-be4f-e2fd1c7b8982")) {                    Plotly.newPlot(                        "c4ca0130-859a-4e96-be4f-e2fd1c7b8982",                        [{"alignmentgroup":"True","hovertemplate":"prompt_template=None\u003cbr\u003emodel_name=%{x}\u003cbr\u003ep_value=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"None","marker":{"color":"#5B5B5B","pattern":{"shape":""},"line":{"width":0}},"name":"None","offsetgroup":"None","orientation":"v","showlegend":true,"textposition":"auto","x":["Taiwan-LLM-7B","Taiwan-LLM-13B","Breeze-7B","TAIDE-7B"],"xaxis":"x","y":[0.9219911249802116,0.1531411886301028,0.249
# ...

# %%
import os
import plotly.express as px
import pandas as pd

model_name_dict ={
    # 'Taiwan-LLM-7B-v2.1-chat':'Taiwan-LLM-7B-v2.1-chat',
    'Taiwan-LLM-7B-v2.0.1-chat':'Taiwan-LLM-7B',
    'Taiwan-LLM-13B-v2.0-chat':'Taiwan-LLM-13B',
    'Breeze-7B-Instruct-v0_1':'Breeze-7B',
    # 'llama2-7b-ccw_cp-tw9_tv-0.5tulu2-0.5xwin':'llama2-7B-tw9-TV',
    # 'llama2-13b-ccw_cp-tw9_tv-0.5tulu2-0.5xwin':'llama2-13B-tw9-TV',
    # 'llama2-7b-ccw_cp-n0_tv_0.5xwin-0.5tulu':'llama2-7B-n0-TV',
    # 'llama2-13b-ccw_cp-n0_tv_0.5xwin-0.5tulu':'llama2-13B-n0-TV',
    # 'llama2-7b-ccw_cp-n1_tv_0.5xwin-0.5tulu':'llama2-7B-n1-TV',
    # 'llama2-13b-ccw_cp-n1_tv_0.5xwin-0.5tulu':'llama2-13B-n1-TV'
    'llama2-7b-ccw_cp-p1_tv_ft-b8.3-capybara-mixed-e3_spin-1':'TAIDE-7B'
} 

# fig_name = ''
# for i in model_name_dict.keys():
#     if i == model_name:
#         fig_name = model_name_dict[i]
#         print(fig_name) 

parent_dir = "/home/u3659277/master-thesis/TWBias/data/gender/result"

### Just modify here ###
origin = "Female" # Male / Female
replace = "T1" if origin == "Female" else "T2"
########################

prompt_list = ["", "no_sys", "no_sys_debias", "sys", "sys_debias"]

df_result = pd.DataFrame(columns=["model_name", "prompt_template", "p_value", "t_value"])

for model_name in model_name_dict.keys():
    for prompt in prompt_list:
        # result_path = f"{parent_dir}/{model_name}/{origin}/{model_name}_{origin}_toxicity_{prompt}.csv"
        result_path = f"{parent_dir}/{model_name}/{origin}_{replace}/{model_name}_{origin}_{replace}_toxicity_{prompt}.csv"
        df = pd.read_csv(result_path)
        p_value = df.loc[2, 'p_value']
        t_statistic = df.loc[2, 't_statistic']
        df_result = pd.concat([df_result, pd.DataFrame({"model_name": [model_name_dict[model_name]], 
                                                            "prompt_template": [prompt or "None"], 
                                                            "t_statistic": [t_statistic]})])


def plot(origin):
    # Define colors for each 'Type'
    type_colors = {
        'None': '#5B5B5B',  # Dark Blue
        'no_sys': '#668957',   # Medium Blue
        'no_sys_debias': '#93c47d',    # Lighter Blue
        'sys': '#f1c232',
        'sys_debias': '#f6da84',
    }

    x_column = 'model_name'
    
    orders = df_result[x_column].unique()
        
    # Using plotly to create an interactive bar plot with custom colors
    fig = px.bar(df_result, x=x_column, y='t_statistic', color='prompt_template', barmode='group',
                labels={'t_statistic': 't_statistic', x_column: x_column, 'propmt_template': 'prompt_template'},
                color_discrete_map=type_colors,  # Apply custom colors
                category_orders={x_column: orders}
                )
    

    xaxis_title = "model name"
        
    # Update layout for a clearer view
    fig.update_layout(title={'text': origin,'font_size': 25},
                    #   xaxis={'categoryorder': 'array'},
                    xaxis_title=xaxis_title,
                    yaxis_title='t-statistic',
                    legend_title='prompt template',
                    # yaxis_type="log",
                    width=800,  # Adjust width as needed
                    height=500,  # Adjust height as needed
                    legend_title_font_size=18,  # Adjust legend title font size
                    legend_font_size=16,  # Adjust legend items font size
                    xaxis_title_font={"size": 20},  # Adjust x-axis title font size
                    yaxis_title_font={"size": 20}
                    )

    # fig.add_hline(y=0.05, line_dash="dash", line_color="#001f3f")

    # Make the bars narrower
    fig.update_traces(marker=dict(line=dict(width=0)))

    # Update x-axis tick font size
    fig.update_xaxes(tickfont=dict(size=18))
    fig.update_yaxes(tickfont=dict(size=15))

    # Show the figure
    fig.show()

plot(origin)
# Out:
# <div>                            <div id="d25407a2-842c-44cd-82af-a2a638fd8356" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d25407a2-842c-44cd-82af-a2a638fd8356")) {                    Plotly.newPlot(                        "d25407a2-842c-44cd-82af-a2a638fd8356",                        [{"alignmentgroup":"True","hovertemplate":"prompt_template=None\u003cbr\u003emodel_name=%{x}\u003cbr\u003et_statistic=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"None","marker":{"color":"#5B5B5B","pattern":{"shape":""},"line":{"width":0}},"name":"None","offsetgroup":"None","orientation":"v","showlegend":true,"textposition":"auto","x":["Taiwan-LLM-7B","Taiwan-LLM-13B","Breeze-7B","TAIDE-7B"],"xaxis":"x","y":[-4.186731642532194,-2.1749088289814527,
# ...

# %%
import os
import math
import numpy as np
import pandas as pd
import plotly.graph_objects as go

model_name_dict ={
    # 'Taiwan-LLM-7B-v2.1-chat':'Taiwan-LLM-7B-v2.1-chat',
    'Taiwan-LLM-7B-v2.0.1-chat':'Taiwan-LLM-7B',
    'Taiwan-LLM-13B-v2.0-chat':'Taiwan-LLM-13B',
    'Breeze-7B-Instruct-v0_1':'Breeze-7B',
    # 'llama2-7b-ccw_cp-tw9_tv-0.5tulu2-0.5xwin':'llama2-7B-tw9-TV',
    # 'llama2-13b-ccw_cp-tw9_tv-0.5tulu2-0.5xwin':'llama2-13B-tw9-TV',
    # 'llama2-7b-ccw_cp-n0_tv_0.5xwin-0.5tulu':'llama2-7B-n0-TV',
    # 'llama2-13b-ccw_cp-n0_tv_0.5xwin-0.5tulu':'llama2-13B-n0-TV',
    # 'llama2-7b-ccw_cp-n1_tv_0.5xwin-0.5tulu':'llama2-7B-n1-TV',
    # 'llama2-13b-ccw_cp-n1_tv_0.5xwin-0.5tulu':'llama2-13B-n1-TV'
    'llama2-7b-ccw_cp-p1_tv_ft-b8.3-capybara-mixed-e3_spin-1':'TAIDE-7B'
} 


## Draw heat map for ethical group
model_path = "/home/u3659277/master-thesis/TWBias/data/ethical_group/result_avg/llama2-7b-ccw_cp-p1_tv_ft-b8.3-capybara-mixed-e3_spin-1"
model_name = model_path.split('/')[-1]
print(model_name)

fig_name = ''
for i in model_name_dict.keys():
    if i == model_name:
        fig_name = model_name_dict[i]
        print(fig_name) 

target_list = [
    ('Hakka', 'T5', 'Hakka'),
    ('W', 'T2', 'W*'),
    ('B', 'T1', 'Hoklo'),
    ('NT', 'T4', 'I*'),
    ('H', 'T3', 'Han'),
]

## Construct empty data
l = len(target_list)
data_list = [] # shape = 4 x (4, # of Category)
category_list = [] # shape = 4 x (# of Category)
t_list = [] # shape = 4 x (4, # of Category)

for r in range(l):
    count = 0
    for c in range(l):
        origin = target_list[r][0]
        replace = target_list[c][1]
        file_path = f"{model_path}/{origin}_{replace}/{model_name}_{origin}_{replace}_category_all_.csv"
        if not os.path.exists(file_path):
            print(file_path, ": file not found!!")
            continue
        df = pd.read_csv(file_path)
        # Add new data & categories
        if count == 0:
            category_list.append(df['Category'])
            data_list.append(np.zeros((l - 1, len(df['Category']))))
            t_list.append(np.zeros((l - 1, len(df['Category']))))
            
        data_list[r][count] = df['p_value']
        t_list[r][count] = df['t_statistic']
        count += 1

## flip data
for i in range(l-1):
    data_list[i] = data_list[i][::-1]
    t_list[i] = t_list[i][::-1]

## custom colorscale
mid_ratio_list = []
for i in range(l-1):
    # max_v, min_v = np.nanmax(data_list[i]), np.nanmin(data_list[i])
    # mid_v = math.log(0.05, 10)
    max_v, min_v = np.nanmax(t_list[i]), np.nanmin(t_list[i])
    mid_v = 0
    mid_ratio = (mid_v - min_v) / (max_v - min_v)
    if mid_ratio < 0:
        mid_ratio = 0
    elif mid_ratio > 1:
        mid_ratio = 1
    mid_ratio_list.append(mid_ratio)

print(mid_ratio_list)

## plot figures
for i in range(l-1):
    if i == l-2:
        print(category_list[i])
        print(data_list[i].shape)
        
    # y_labels
    y = [f"{target_list[i][2]}→{target_list[j][2]}" for j in range(l) if j != i]
    
    # Define custom color scale for different value segments
    mid_ratio = mid_ratio_list[i]
    colorscale = [
        [0, '#cf3440'],  # Lower segment color scale 
        [mid_ratio, '#ffffff'],  # Middle segment color scale
        [1, '#4b8333']  # Upper segment color scale  #84917e
    ]
    nan_color = "#a9a9a9"
    
    fig = go.Figure(data=go.Heatmap(
        z=t_list[i], 
        x=category_list[i], 
        y=y[::-1], # flip data 
        colorscale=colorscale,
        colorbar=dict(title='t-statistics')), 
        layout=go.Layout(
            plot_bgcolor=nan_color
        )
    )
    
    # Add symbols
    for j in range(len(t_list[i])):
        for k in range(len(t_list[i][j])):
            # t_value = t_list[i][j][k]
            # print(t_value)
            # if t_value > 0:
            #     symbol = 'triangle-up'
            #     color = '#fadaba'
            # else:
            #     symbol = 'triangle-down'
            #     color = '#20124d'
            p_value = data_list[i][j][k]
            if p_value < 0.05:
                symbol = 'star'
                color = '#20124d'
                fig.add_trace(go.Scatter(x=[category_list[i][k]], y=[y[-1-j]], mode='markers', marker=dict(symbol=symbol, size=15, color=color), showlegend=False))

    fig.update_xaxes(showgrid=False)
    fig.update_yaxes(showgrid=False)

    fig.update_layout(
        title=fig_name,
        title_font=dict(size=22),
        yaxis_title='Target → Replaced Target',
        xaxis_title='Attribute Category',
        xaxis=dict(tickfont=dict(size=16)),
        yaxis=dict(tickfont=dict(size=15)),
        # width=120*len(category_list[i]),
        width = 750,
        height=500,
        title_x=0.5,
        xaxis_side='bottom',
        margin=dict(t=150),
        coloraxis_colorbar=dict(
            title='Color Scale',  # Colorbar title
            len=0.75,  # Length of the colorbar
            yanchor='bottom',  # Anchor point of the colorbar
            ticks='outside',  # Place ticks outside the colorbar
        ),
    )

    fig.show()
# Out:
# llama2-7b-ccw_cp-p1_tv_ft-b8.3-capybara-mixed-e3_spin-1
# TAIDE-7B
# /home/u3659277/master-thesis/TWBias/data/ethical_group/result_avg/llama2-7b-ccw_cp-p1_tv_ft-b8.3-capybara-mixed-e3_spin-1/Hakka_T5/llama2-7b-ccw_cp-p1_tv_ft-b8.3-capybara-mixed-e3_spin-1_Hakka_T5_category_all_.csv : file not found!!
# /home/u3659277/master-thesis/TWBias/data/ethical_group/result_avg/llama2-7b-ccw_cp-p1_tv_ft-b8.3-capybara-mixed-e3_spin-1/W_T2/llama2-7b-ccw_cp-p1_tv_ft-b8.3-capybara-mixed-e3_spin-1_W_T2_category_all_.csv : file not found!!
# /home/u3659277/master-thesis/TWBias/data/ethical_group/result_avg/llama2-7b-ccw_cp-p1_tv_ft-b8.3-capybara-mixed-e3_spin-1/B_T1/llama2-7b-ccw_cp-p1_tv_ft-b8.3-capybara-mixed-e3_spin-1_B_T1_category_all_.csv : file not found!!
# /home/u3659277/master-thesis/TWBias/data/ethical_group/result_avg/llama2-7b-ccw_cp-p1_tv_ft-b8.3-capybara-mixed-e3_spin-1/NT_T4/llama2-7b-ccw_cp-p1_tv_ft-b8.3-capybara-mixed-e3_spin-1_NT_T4_category_all_.csv : file not found!!
# ...

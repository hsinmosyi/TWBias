# %%
import numpy as np
import pandas as pd

# %%
from sklearn.metrics import cohen_kappa_score

# %%
df = pd.read_csv('/home/u3659277/master-thesis/analysis_data/data_quality/female_toxicity.csv')
df
# Out:
#     Id        Answer      Label 1      Label 2      Label 3
# 0     1  沒有 污辱/攻擊 言論  沒有 污辱/攻擊 言論  沒有 污辱/攻擊 言論  沒有 污辱/攻擊 言論
# 1     2  沒有 污辱/攻擊 言論  沒有 污辱/攻擊 言論  沒有 污辱/攻擊 言論  沒有 污辱/攻擊 言論
# 2     3  沒有 污辱/攻擊 言論  沒有 污辱/攻擊 言論  沒有 污辱/攻擊 言論  沒有 污辱/攻擊 言論
# 3     4  沒有 污辱/攻擊 言論  沒有 污辱/攻擊 言論  沒有 污辱/攻擊 言論  沒有 污辱/攻擊 言論
# 4     5  沒有 污辱/攻擊 言論  沒有 污辱/攻擊 言論  沒有 污辱/攻擊 言論  沒有 污辱/攻擊 言論
# 5     6  沒有 污辱/攻擊 言論   有 污辱/攻擊 言論   有 污辱/攻擊 言論  沒有 污辱/攻擊 言論
# 6     7  沒有 污辱/攻擊 言論  沒有 污辱/攻擊 言論  沒有 污辱/攻擊 言論  沒有 污辱/攻擊 言論
# 7     8  沒有 污辱/攻擊 言論  沒有 污辱/攻擊 言論  沒有 污辱/攻擊 言論  沒有 污辱/攻擊 言論
# 8     9  沒有 污辱/攻擊 言論  沒有 污辱/攻擊 言論  沒有 污辱/攻擊 言論  沒有 污辱/攻擊 言論
# 9    10  沒有 污辱/攻擊 言論  沒有 污辱/攻擊 言論  沒有 污辱/攻擊 言論  沒有 污辱/攻擊 言論
# 10   11  沒有 污辱/攻擊 言論  沒有 污辱/攻擊 言論   有 污辱/攻擊 言論  沒有 污辱/攻擊 言論
# 11   12  沒有 污辱/攻擊 言論  沒有 污辱/攻擊 言論  沒有 污辱/攻擊 言論  沒有 污辱/攻擊 言論
# 12   13  沒有 污辱/攻擊 言論  沒有 污辱/攻擊 言論  沒有 污辱/攻擊 言論  沒有 污辱/攻擊 言論
# 13   14  沒有 污辱/攻擊 言論  沒有 污辱/攻擊 言論  沒有 污辱/攻擊 言論  沒有 污辱/攻擊 言論
# 14   15  沒有 污辱/攻擊 言論  沒有 污辱/攻擊 言論  沒有 污辱/攻擊 言論  沒有 污辱/攻擊 言論
# ...

# %%
y1 = df['Answer']
y2 = df['Label 3'] # Label 1	Label 2	Label 3

# %%
cohen_kappa_score(y1, y2)
# Out:
# 0.8666666666666667
